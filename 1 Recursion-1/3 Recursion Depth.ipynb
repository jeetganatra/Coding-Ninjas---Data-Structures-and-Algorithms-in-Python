# %%
def fact(n):
    if n == 0:
        return 1
    return n*fact(n-1)

n = int(input())
fact(n)
# Out:
# 2500
# ...

# %%
def fact(n):
    if n == 0:
        return 1
    return n*fact(n-1)

n = int(input())
fact(n)

# %% [markdown]
# ### Set the recusion limit using sys
#
# import sys
#
#
# sys.setrecursionLimit(3000)
