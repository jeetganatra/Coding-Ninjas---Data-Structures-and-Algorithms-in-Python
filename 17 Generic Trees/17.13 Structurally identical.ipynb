# %%
class treeNode:
    def __init__(self, data):
        self.data = data
        self.children = []

import queue        
def isIdentical(tree1, tree2):
    if tree1 == None and tree2 == None:
        return True
    
    if tree1 == None or tree2 == None:
        return False
    
    q1 = queue.Queue()
    q2 = queue.Queue()
    
    q1.put(tree1)
    q2.put(tree2)
     
    l1 = []
    l2 = []
    
    while(not(q1.empty())):
        curr = q1.get()
        l1.append(curr)
        for child in curr.children:
            l1.append(child)
            q1.put(child)            
    
    while(not(q2.empty())):
        curr = q2.get()
        l2.append(curr)
        for child in curr.children:
            l2.append(child)
            q2.put(child)
            
    print(len(l1), l1)
    print(len(l2), l2)
    
    if len(l1) == len(l2):
        for i in range(len(l1)):
            print(l1[i].data, end = " ")
            print(l2[i].data)
            if l1[i].data != l2[i].data:
                print("Data not equal")
                return False
        return True
    else:
        return False
            
def createLevelWiseTree(arr):
    root = treeNode(int(arr[0]))
    q = [root]
    size = len(arr)
    i = 1
    while i<size:
        parent = q.pop(0)
        childCount = int(arr[i])
        i += 1
        for j in range(0,childCount):
            temp = treeNode(int(arr[i+j]))
            parent.children.append(temp)
            q.append(temp)
        i += childCount
    return root

# Main
arr1 = list(int(x) for x in input().strip().split(' '))
#arr1 = [10, 3, 20, 30, 40, 2, 40, 50, 0, 0, 0, 0]
tree1 = createLevelWiseTree(arr1)
arr2 = list(int(x) for x in input().strip().split(' '))
#arr2 = [10, 3, 20, 30, 40, 2, 40, 50, 0, 0, 0, 0]
tree2 = createLevelWiseTree(arr2)
if isIdentical(tree1, tree2):
    print('true')
else:
    print('false')
# Out:
# 10 3 20 30 40 2 40 50 0 0 0 0
# 10 3 2 30 40 2 40 50 0 0 0 0
# 11 [<__main__.treeNode object at 0x00000201D154D550>, <__main__.treeNode object at 0x00000201D154D710>, <__main__.treeNode object at 0x00000201D154D438>, <__main__.treeNode object at 0x00000201D154D2B0>, <__main__.treeNode object at 0x00000201D154D710>, <__main__.treeNode object at 0x00000201D154D588>, <__main__.treeNode object at 0x00000201D154D5C0>, <__main__.treeNode object at 0x00000201D154D438>, <__main__.treeNode object at 0x00000201D154D2B0>, <__main__.treeNode object at 0x00000201D154D588>, <__main__.treeNode object at 0x00000201D154D5C0>]
# 11 [<__main__.treeNode object at 0x00000201D154D828>, <__main__.treeNode object at 0x00000201D154D048>, <__main__.treeNode object at 0x00000201D154D518>, <__main__.treeNode object at 0x00000201D154D898>, <__main__.treeNode object at 0x00000201D154D048>, <__main__.treeNode object at 0x00000201D154D2E8>, <__main__.treeNode object at 0x00000201D154D780>, <__main__.treeNode object at 0x00000201D154D518>, <__main__.treeNode object at 0x00000201D154D898>, <__main__.treeNode object at 0x00000201D154D2E8>, <__main__.treeNode object at 0x00000201D154D780>]
# 10 10
# 20 2
# Data not equal
# false
